# %% [markdown]
# <img src="https://raw.githubusercontent.com/insaid2018/Term-1/master/Images/INSAID_Full%20Logo.png" width="240" height="360" />
# # ASSIGNMENT - DATA VISUALIZATION

# %%
import pandas as pd
pokemon = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/Pokemon.csv", index_col=0)
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## UNIVARIATE PLOTTING

# %% [markdown]
# ### 1. Create a bar chart using "Type 1" and its frequency.

# %%
import pandas as pd
def create():
    # your code here using Type1 and its frequency
    pokemon['Type 1'].value_counts().plot.bar()
#     print(pokemon['Type 1'].value_counts())
    return None
create()

# %% [markdown]
# ### 2. Create a line chart using "HP" and its frequency.

# %%
import pandas as pd
def create():
    # your code here using HP and its frequency
    pokemon['HP'].value_counts().sort_index().plot.line()
    return None
create()

# %% [markdown]
# ### 3. Create an area chart using "Total" and its frequency.

# %%
import pandas as pd
def create():
    # your code here using Total and its frequency
    pokemon['Total'].value_counts().sort_index().plot.area()
    return None
create()

# %% [markdown]
# ### 4. Create a histogram using "Total" and its frequency.

# %%
import pandas as pd
def create():
    # your code here using Total and its frequency
    pokemon['Total'].plot.hist()
    return None
create()

# %% [markdown]
# ## BIVARIATE PLOTTING

# %% [markdown]
# ### 5. Create a scatter plot using "Attack" and "Defense".

# %%
import pandas as pd
def create():
    # your code here
    pokemon.plot.scatter(x="Attack", y="Defense")
    return None
create()

# %% [markdown]
# ### 6. Create a hex plot using "Attack" and "Defense" with gridsize of 25.

# %%
import pandas as pd
def create():
    # your code here
    pokemon.plot.hexbin(x="Attack", y="Defense", gridsize=25)
    return None
create()

# %% [markdown]
# ### 7. Create a stacked chart on "Legendary" and "Generation" columns, for stacking on "Attack" and "Defense" values.

# %%
import pandas as pd
def create():
    # your code here (Perform group by and mean respectively)
    grouped_pokemon = pokemon.groupby(['Legendary', 'Generation']).mean()[['Attack', 'Defense']]
    # call the created variable to plot
    grouped_pokemon.plot.bar(stacked=True)
    return None
create()

# %% [markdown]
# ### 8. Create a bivariate plot line on "HP", "Attack", "Defense", "Sp.Atk", "Sp.Def", "Speed", grouped by "Generation".

# %%
import pandas as pd
def create():
    # perform group by and mean for the mentioned variables
    grouped_pokemon = pokemon.groupby(['Generation']).mean()[['HP', 'Attack','Defense','Sp. Atk', 'Sp. Def', 'Speed']]
    # call the created variable to plot
    grouped_pokemon.plot.line()
    return None
create()

# %% [markdown]
# ### 9. Create a pairplot dropping "Name" and using "Legendary" as hue and implement a palette of your choice(size=2).

# %%
import seaborn as sns
def create():
    # your code her for detailed and distinctive plotting including hue, palette and size
    sns.pairplot(pokemon.drop("Name", axis=1),hue="Legendary",size=2,palette="dark")
    return None
create()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## MULTIVARIATE PLOTTING

# %% [markdown]
# ### 10. Create a multivariate scatter plot using "Attack" and "Defense" having hue as "Legendary" and appropriate markers as 'x' and 'o'.

# %%
import seaborn as sns
def create():
    # your code here (use markers to distinguish data points and hue)
    sns.lmplot(data=pokemon,x="Attack", y="Defense", hue="Legendary", markers=["x","o"],fit_reg=False)
    return None
create()

# %% [markdown]
# ### 11. Create a box plot using "Generation" and "Total" with hue as "Legendary".

# %%
import seaborn as sns
def create():
    # your code here
    sns.boxplot(data=pokemon, x="Generation", y="Total", hue="Legendary", palette="dark")
    return None
create()

# %% [markdown]
# ### 12. Create a heatmap using "HP", "Attack", "Sp. Atk", "Defense", "Sp. Def", "Speed" .

# %%
import seaborn as sns
def create():
    # your code here (Hint: use annot=True)
    sns.heatmap(data=pokemon[["HP","Attack","Sp. Atk","Defense", "Sp. Def","Speed"]].corr(),annot=True)
    return None
create()

# %% [markdown]
# ### 13. Create  a parallel coordinates chart  based on "Psychic" and "Fighting" skills on "Type 1", "Attack", "Sp. Atk", "Defense", "Sp. Def".

# %%
import pandas as pd
from pandas.plotting import parallel_coordinates
def create():
    #your code here (Hint: use .isin and .loc respectively)
    p = (pokemon[(pokemon['Type 1'].isin(["Psychic", "Fighting"]))]
         .loc[:, ['Type 1', 'Attack', 'Sp. Atk', 'Defense', 'Sp. Def']]
    )
    # call the created variable
    parallel_coordinates(p, 'Type 1',color=["red","green"])
    return None
create()

# %% [markdown]
# ### 14. Create a swarmplot using "Generation" and "Defense" marking "Legendary" as hue and with any palette of your choice.

# %%
import seaborn as sns
def create():
    # your code here
    sns.swarmplot(data=pokemon, x="Generation",y="Defense", hue="Legendary", palette="dark")
    return None
create()

# %% [markdown]
# ### 15. Create a bokeh plot using Attack and Total keeping names as the categorical variables.

# %%
# Bokeh packages
from bokeh.io import output_file,show,output_notebook,push_notebook
from bokeh.plotting import *
from bokeh.models import ColumnDataSource,HoverTool,CategoricalColorMapper,Slider
from bokeh.layouts import row,column,gridplot,widgetbox
from bokeh.models.widgets import Tabs,Panel
from bokeh.io import push_notebook
from ipywidgets import interact
output_notebook()
import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e0c82a8b-416c-4b49-a3f0-6a28d9cc8cd3">Loading BokehJS ...</span>
#     </div>

# %%
from IPython.html.widgets import interact
data = pokemon.set_index("Generation")
x = data.loc[1].Attack
y = data.loc[1].Total
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7e48aa4f-77a3-4248-8e22-5b51fce75ebf">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import Figure,figure, output_file, show, output_notebook
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, CustomJS, Slider, HoverTool
output_notebook()

def create ():
    # your code here (using ColumDataScource, feed values for the x and y together with speed and generation)
    source = ColumnDataSource(data={
        "x": data.loc[1].Attack,
        "y": data.loc[1].Total,
        "Name" : data.loc[1].Name,
        "HP" : data.loc[1].HP,
        "Legendary" : data.loc[1].Legendary
    })
    # using the plot function, provide dimensions as suitable for it.
    factors = data.Name.unique().tolist()
    colors = ["red","green","blue","black","orange","brown","grey","purple","yellow","cyan","pink","peru"]
    color_mapper = CategoricalColorMapper(factors=factors,palette=colors)
    hover = HoverTool(tooltips = [("Name of Pokemon","@Name"),("Legendary pokemon","@Legendary"),("HP of pokemon","@HP")])
    # create a unique list for names.
    # properly code for plot title, legends and axis-name
    plot=figure(title ="Pokemon",tools=[hover,"crosshair","pan","box_zoom"])
    plot.circle("x","y",source=source,color=dict(field="Name", transform=color_mapper), legend='Name',hover_color ="red")
    show(plot,notebook_handle=True)

def update_plot(x_axis ,y_axis,Generation=1):
    c1 = x_axis
    c2 = y_axis
    new_data = {
        'x'       : data.loc[Generation,c1],
        'y'       : data.loc[Generation,c2],
        "Name"    : data.loc[Generation].name,
        "HP"  : data.loc[Generation].HP,
        "Legendary"  : data.loc[Generation].Legendary
    }
    source.data = new_data
    plot.xaxis.axis_label = c1
    plot.yaxis.axis_label = c2
    push_notebook()
    show(plot,notebook_handle=True)
    return None
create()
interact(update_plot,number=(0,15,1))
show(plot,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cbea7fab-e889-4225-ad04-6ed5ce128ff3">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c893e8eb-8d53-4eaf-8ec4-442af11c5e27"></div>
# </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-16b35175a375> in <module>()
#      41     return None
#      42 create()
# ---> 43 interact(update_plot,number=(0,15,1))
#      44 show(plot,notebook_handle=True)
#
# C:\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in __call__(self, _InteractFactory__interact_f, **kwargs)
#     521         #    def f(*args, **kwargs):
#     522         #        ...
# --> 523         w = self.widget(f)
#     524         try:
#     525             f.widget = w
#
# C:\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in widget(self, f)
#     437             The function to which the interactive widgets are tied.
#     438         """
# --> 439         return self.cls(f, self.opts, **self.kwargs)
#     440
#     441     def __call__(self, __interact_f=None, **kwargs):
#
# C:\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in __init__(self, _interactive__interact_f, _interactive__options, **kwargs)
#     181         self.auto_display = __options.get("auto_display", False)
#     182
# --> 183         new_kwargs = self.find_abbreviations(kwargs)
#     184         # Before we proceed, let's make sure that the user has passed a set of args+kwargs
#     185         # that will lead to a valid call of the function. This protects against unspecified
#
# C:\anaconda3\lib\site-packages\ipywidgets\widgets\interaction.py in find_abbreviations(self, kwargs)
#     281             for name, value, default in _yield_abbreviations_for_parameter(param, kwargs):
#     282                 if value is empty:
# --> 283                     raise ValueError('cannot find widget or abbreviation for argument: {!r}'.format(name))
#     284                 new_kwargs.append((name, value, default))
#     285         return new_kwargs
#
# ValueError: cannot find widget or abbreviation for argument: 'x_axis'
